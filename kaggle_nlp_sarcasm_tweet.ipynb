# %% [markdown]
# # Kaggle Competition using NLP

# %%
# import relevant packages

import pandas as pd
import numpy as np

# %%
# get data loaded into dataframe
validation_data = pd.read_csv('nlp-getting-started/test.csv')
train_data = pd.read_csv('nlp-getting-started/train.csv')

# %%
train_data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print(train_data.isna().sum())
print(len(train_data))
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64
# 7613

# %%
# Lets get rid of the keyword and location columns because i don't reckon we need them
train_data = train_data.drop(columns = ['keyword','location'])

# %%
# Lets clean up the data in text
# importing all necessary modules
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
warnings.filterwarnings(action='ignore')
from pathlib import Path
import re
import nltk
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer


# Preparing the dataset
#all_sentences = nltk.sent_tokenize(all_data_string)
#all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

def clean_data(data):
    # This function takes an array of strings and returns an array of cleaned up strings
    cleaned_data = []
    for row,texts in enumerate(data):
        texts = texts.lower()
        # remove special characters
        texts = texts.replace(r"(http|@)\S+", "")
        texts = texts.replace(r'http\S+',"")
        texts = texts.replace(r"::", " ")
        texts = texts.replace(r"’", "")
        texts = texts.replace(r",", " ")
        texts = texts.replace(r"[^a-z\':_]", " ")
        texts = texts.replace("#","")
        texts = texts.replace("!","")
        texts = texts.replace("?","")
        # remove repetition
        # Transform short negation form
        texts = texts.replace(r"(can't|cannot)", 'can not')
        texts = texts.replace(r"n't", ' not')
        # Remove stop words
        stopwords = nltk.corpus.stopwords.words('english')
        stopwords.remove('not')
        stopwords.remove('nor')
        stopwords.remove('no')
        cleaned_line = ''
        for word in texts.split(" "):
            if word not in stopwords:
                cleaned_line = cleaned_line + " " + word
        cleaned_data.append(cleaned_line)
    return cleaned_data

X = clean_data(train_data['text'])
y = np.array(train_data['target'])
#X_test = clean_data(test_data['text'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_test
# Out:
# [' new weapon cause un-imaginable destruction.',
#  ' f$&amp;@ing things gishwhes got soaked deluge going pads tampons. thx @mishacollins @/@',
#  ' dt @georgegalloway: rt @galloway4mayor: \x89ûïthe col police catch pickpocket liverpool stree... http://t.co/vxin1goq4q',
#  ' aftershock back school kick great. want thank everyone making possible. great night.',
#  ' response trauma children addicts develop defensive self - one decreases vulnerability. (3',
#  ' @calum5sos look like got caught rainstorm amazing disgusting time',
#  ' favorite lady came volunteer meeting\nhopefully joining youth collision excite http://t.co/ij0wq490cs',
#  ' @brianroemmele ux fail emv - people want insert remove quickly like gas pump stripe reader. 1 person told crashed pos',
#  ' ca not find ariana grande shirt  fucking tragedy',
#  ' murderous story america\x89ûªs first hijacking http://t.co/eyugk6byxr',
#  ' akilah world news cop pulls man car avoid ... http://t.co/vn2fnmy7li',
#  ' walk plank sinking ship',
#  ' @zak_bagans pets r like part family. love animals. last 2 pets rescued breaks heart animals mistreated',
#  ' use perforated metal shear panel sfor seismic-resistant applications http://t.co/cx5ojh2dr4',
#  ' answer friend yelling wind-my latest article http://t.co/lbmekyphm5.pls read share - thanks http://t.co/9nwajli9cr',
#  ' woman electrocuted red redblood videoclip http://t.co/9pymm2ruwf ',
#  ' bringing tornadoes floods. bringing climate change. god america plaguing her\n \nfarrakhan quote',
#  ' savages leaked thomas brady gangstermail account wonder quick fatality samsung mobile b real son.',
#  ' [withering] death. album found [undermine]d backyard cat [inundated] floor [mustering] cat food.',
#  ' fedex no longer transport bioterror germs wake anthrax lab mishaps http://t.co/c0p3sesqwm via @usatoday',
#  ' @amirkingkhan would annihilated might well thank @floydmayweather',
#  ' today\x89ûªs storm pass; let tomorrow\x89ûªs light greet kiss. bask loving warmth; let soul return bliss.',
#  ' battlefield 4 funny moments - dukes hazard undercover soldier mav t... https://t.co/ju8nfpnedl via @youtube',
#  ' magic city mayhem: kissimmee adventures  aug. 5 2015 http://t.co/fpyru5golh',
#  ' social casualty mtvhottest 5sos',
#  ' watch airport get swallowed sandstorm minute http://t.co/1tr2kvxctw',
#  " lukebox something first responders/ military true hero's besides music",
#  ' body bags https://t.co/0mcxc68gzd',
#  ' fedex not willing transport research specimens potential bioterror pathogens wake anthrax lab mishaps  http://t.co/cm8uni1mrg',
#  ' red cross re-opens shelter bickleton school 25 homes evacuated &amp; around roosevelt wa due wildfire. liveonk2',
#  ' ears bleeding hate stefano',
#  ' hellfire don\x89ûªt even want think mention let\x89ûªs not anything leads islam',
#  ' know anyone looking move hammond share listing http://t.co/3xn1soh4bb',
#  ' new now: different (fnaf fanfiction): trixie_drowned / 2 pageshi awesome proxies ... http://t.co/366nhtg3tz wattpad promo',
#  ' reddit updates content policy promises quarantine \x89û÷extremely offensive\x89ûª communities http://t.co/kmtwa3n1gf',
#  " not think one second i'm drown memory. baby ai not worth whiskey.",
#  ' crackdown 3 destruction restricted multiplayer: crackdown 3 impressed earlier week demonstratio... http://t.co/lmwkjsycgj',
#  ' nhs england announces new plan meet emergency care targets http://t.co/0x2bieqxpv',
#  ' autoinsurance industry clueless driverlesscars : markets : money times http://t.co/ydetwgribk',
#  ' @raineishida lol...im nervous wreck :p',
#  " oh shit rly sheeting\naaaaaand there's thunder lightning\ni missed summer storms",
#  ' crushed gym crushed butterfinger flurry clearly priorities straight ',
#  ' @nxwestmidlands huge fire wholesale markets ablaze http://t.co/rwzbfvnxer',
#  ' tubestrike derailed robertwelch cutlery offers get back track http://t.co/bq8kyi7gng http://t.co/gnzwxqktam',
#  ' obliterated',
#  ' u.s national park services tonto national forest: stop annihilation salt river wild horse... https://t.co/sw1sbua3mn via @change',
#  ' breakingnews rly tragedy mp: live recount horror: \x89ûïwhen saw coaches train plunging wa... http://t.co/eyorbmf3o3',
#  ' new expansion ideas - bard class holy trinity + 1 http://t.co/egioxbaboe',
#  ' wtf mom drowned child',
#  ' route complex fire update (route complex wildfire): fire update: route complex thursday morning aug... http://t.co/ns5lbs5zup cafire',
#  ' tubestrike tfl workers may trouble planning downtime. hope none need emergency services. http://t.co/icsfdsifqb',
#  ' death palestinian toddler arson\nattack israel cracks jewish',
#  ' cool @garbanzobean23 news cutest indot worker might little bias  http://t.co/g7k9tqvqbk',
#  ' totally agree. rape kill destroy leave land desolate. action needs happen swarm swells. https://t.co/twcds433yi',
#  ' another day another excellent @_dangerousbeans porridge. seriously people. blood orange porridge phenomenal.',
#  ' @eric_tsunami worry',
#  ' thingsihate \nwatching someone care head total destruction not able anything.',
#  ' @sethalphaeus personal favorites include paramore muse green day royal blood 5sos',
#  " progressive greetings\n\nin month students would set pens ablaze torch publications'... http://t.co/9fxpixqujt",
#  ' swiss kosher hotel bridge collapse injures five people - http://t.co/txiestox5n @jewishpress',
#  ' get load welfare loving sponge....a blight society. http://t.co/rrzbzgo48n',
#  " pbban (temporary:300) fighterdena @'armageddon | not kill | flags | fast xp' reason",
#  " @thesmallclark 'he'll kill instead survived shot. not exactly know. fled scene pulled trigger with---",
#  ' one thing sure of. never bush fires scotland ground always soaking wet',
#  ' @trollkrattos juan carlos salvador secret tips get 100.000 riot points lol check secret bio',
#  ' ignition knock (detonation) sensor-senso standard fits 02-06 acura rsx 2.0l-l4 http://t.co/vzaiqamdcp http://t.co/ycecn44c8p',
#  ' quote never let problems ruin faith.',
#  " nuu fam fwt i'm leave body bag",
#  ' 2 injured 1 missing bridge collapse central mexico - fox news latino http://t.co/l0unafly0y',
#  ' god forbid true california enough problems severe drought &amp; wild fires. http://t.co/cmsgexm4fc nuclear power sanonofre',
#  ' helpme friend ticketed police wayne county michigan never- sending poverty cycle. help',
#  ' @allahsfinest12 ...death muslims',
#  ' last tree cut last fish eaten last stream poisoned realize you... http://t.co/hskl0vq2d2',
#  ' yeah 1:57  |  lamb god - rock ring 2015 - intro+desolation hd https://t.co/lem5z1nfk3 via @youtube',
#  ' 2 burning man tickets + vehicle pass - full read ebay http://t.co/b0es3ziork http://t.co/juiit2yfvo',
#  ' usa: breaking news: chemical spill/evacuations/red cross emergency http://t.co/007npen6lg',
#  ' someone split mudslide w get work',
#  ' tigers wonder much upheaval team affecting different players tonight',
#  ' even u weapon badge gonna put choppas ass',
#  ' never screamed loud https://t.co/pc3h1ne4g0',
#  ' lyf needs quality certain sense security. person ca not trust cause stress emotional upheaval.',
#  ' @christinalavv @lindsay_wynn3 saw tweets feel really attacked',
#  ' finally demolished spring 2013 property sat vacant since. just\x89û_: saddlebrooke... http://t.co/b8n6e4ryvz',
#  ' large explosion rocks aluminum plant southeast missouri re:naomi-no logo http://t.co/0wdseihyqu',
#  " deepak chopra's epic twitter meltdown http://t.co/ethgagpy5g",
#  " flip side i'm walmart bomb everyone evacuate stay tuned blow not",
#  " not understand 'taking' life trophy. violent killing. http://t.co/neqw47e1uj cecilthelion badchoices bantrophyhunting",
#  " @mallelis gotten post-battle we're-on-a-desolate-planet below-the-mason-dixon-line style electro violin playing yet",
#  ' @nwspocatello bg-16: far brunt storm north. grayed w/ dust &amp; rain n blue sky interspersed w/ clouds s.',
#  " i've trying write theological short story monster living sinkhole. heard brooklyn. accidentalprophecy",
#  ' metepec mexico - night disaster...e(oficial) @ nitclub mì¼sica mì¼sica http://t.co/wtfjf9jjzs',
#  ' @alextucker volcano bowl drink',
#  ' 8-minute fat-burning routine that\x89ûªs also really fun http://t.co/g2h7xnecd8 fat weightless  fatburning burnfat skinny workout',
#  ' factors consider hiring demolition company noxdv',
#  ' tbt remember time patrick kane attacked cab driver .20',
#  ' messed feeling like hurricane damaged broken home',
#  ' totally unprepared emp attack. china russia probably isis possess them. 90% fatalities. pushing',
#  ' @youssefyamani add fez weather equation best recipe disaster.',
#  ' rated hobbit: desolation smaug (2013) 7/10  imdb http://t.co/djdewd13wr',
#  ' storm headed towards idaho falls blowing dust &amp; winds 60 mph.  us hwy 20 &amp; i15 look out.  idwx http://t.co/0cr74m1uxm',
#  ' flooding kills 166 displace one million pakistan http://t.co/icfql7i9op\n\nat least 166 people killed nearly 11 lakh\x89û_',
#  " @flames_nation that's optimistic side me. no doubt tough. done. feel like games pivot defense.",
#  ' @gettinglost @jennellensbb @muncle_jim said superficial wounds pepper spray damage.',
#  ' socialwots: globi_inclusion: rt nrc_middleeast: sandstorm engulfs caravans tents zaatari refugee camp \x89û_ http://t.co/xbnlsbzzgi',
#  ' reddit quarantine offensive content http://t.co/8s0mtwrumq technology technews puledo_tech_update',
#  " @ctaztrophe31 everything must ok listening 'sandstorm' now...",
#  ' police: teenagers arrested curfew violations evanston riding stolen bicycles: two teenagers taken cus...  chicago news',
#  ' finna storm. fuck back boutta start hurting like mf ',
#  ' us ddnt get english  rt @reign_coco: world inundated ostentatious people stay woke',
#  " policylab @cecanf's last public hearing nyc today tomorrow address child abuse neglect fatalities http://t.co/n2cy3z4tpb",
#  ' twelve feared killed pakistani air ambulance helicopter crash http://t.co/xum8ylcb4q',
#  ' apply muslims/terrorism\nor catholicism/homophobia',
#  ' civilian casualties afghanistan reach record high http://t.co/r8ptvfuh5x http://t.co/npckk0tleq',
#  ' obama declares disaster typhoon-devastated saipan: obama signs disaster declaration northern marians a... http://t.co/vts9cayibc',
#  ' thunderstorm helsinki\nthunder lightning lightningstrike thunderstorm nature helsinki\x89û_ https://t.co/rjjxucx5pm',
#  ' @vickie627 desert storm unqualified victory treaty signed.  clinton situation got worse violent. tcot',
#  ' @bigsim50 nah philly pundits half cause. set buildings fire report buildings fire.',
#  ' deep crew help california wild fires http://t.co/qkz2sp06xn via @thedayct',
#  ' japan marks 70th anniversary hiroshima atomic bombing http://t.co/93vqkdfgnr',
#  ' correction: tent collapse story http://t.co/jxs50fkvik',
#  ' @arovolturi3000 survived magic  searching wood survivors outside london',
#  " i'm obliterated",
#  ' ruin everything ',
#  ' 26 people screamed right ear week camp. twenty-six still 1/2 day left. cedarglade2015',
#  ' no better feeling seeing stage day ones...... 22 year friendships still body bagging mics together.',
#  ' exporting food wont solve problem. africans end famine n poverty solving control tribal wars. https://t.co/uttanbigrx',
#  ' burned 129 calories 24 minutes walking 3.5 mph brisk pace myfitnesspal',
#  ' arson suspect linked 30 fires caught northern california http://t.co/wnuqqatttp (via @latimes)',
#  ' survivors shanghai ghetto reunite 70 years - http://t.co/1ki8lgvay4 shanghai china ',
#  ' refugio oil spill may costlier bigger projected http://t.co/xcolwugfjg',
#  ' @saintrobinho86 someone bottom every league. tonight clearly demonstrated lions - sunk',
#  ' @jake_blight @wealilknowa cunt',
#  ' floods cause damage death across asia | media content | http://t.co/a2myutpdiq | 05.08.2015 http://t.co/xrskt0s9lz',
#  ' camera art photography http://t.co/tjgxdc3d5p 0215 new boltåêcyclone dr pp-400dr dual outlet power packåêfor external camera flash\n\n$30\x89û_',
#  ' dialyses grandpa oh lord blood makes light headed',
#  " the_af comments 'new evidence japan's effort build atom bomb end wwii' - http://t.co/hctxghr2yf",
#  ' 4 printable emergency plan templates\nhttp://t.co/naex0q1ax0',
#  ' world class tgirl ass 02 - scene 4 - pandemonium http://t.co/iwcu3dgi1a',
#  " mmmmmm i'm burning.... i'm burning buildings i'm building.... oooooohhhh oooh ooh...",
#  ' credit @pfannebeckers inspiring rediscover fantabulous tbt http://t.co/wmhy47xkil',
#  ' @cyberdemon531 hope mountain dew erodes throat floods lungs leaving drown death',
#  ' cuban leader extends sympathy vietnam flooding http://t.co/qcyxwr2rdv',
#  ' @alexbelloli seemed like pages order',
#  " they've come back &gt;&gt; flying ant day: capital deluged annual swarm winged insects http://t.co/mnkoyz76cp",
#  ' fedex no longer transport bioterror germs wake anthrax lab mishaps http://t.co/pwamg8ozj4',
#  ' south sac i5 / i5 43rd ave ofr **trfc collision-no inj** http://t.co/gpxqbyzyu4',
#  ' omg cain dies emotional wreck emmerdale',
#  ' gets battlefield 3 screams mic cunts',
#  ' @skarletan åç storm. violent swell emotions nothing.',
#  ' severe t-storm warning union county ~3:45pm. top threats include heavy rain lightning &amp; damaging winds. http://t.co/xwoevmk0aa',
#  ' aftershock https://t.co/jv8ppkhjy7',
#  ' gonna take break work.... gotta right carlilescanoelivery lovemyjob http://t.co/zo8rsqura2',
#  ' listen believe casualties cool one best albums ever was.',
#  ...]

# %% [markdown]
# # Standard ML models first using Tfidf and count vectorizers

# %%
# https://github.com/aditya-xq/Text-Emotion-Detection-Using-NLP

from sklearn.feature_extraction.text import TfidfVectorizer

# Extracting TF-IDF parameters
tfidf = TfidfVectorizer(max_features=1000, analyzer='word',ngram_range=(1,3))
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.fit_transform(X_test)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Extracting Count Vectors Parameters
count_vect = CountVectorizer(analyzer='word')
count_vect.fit(X_train)
X_train_count =  count_vect.transform(X_train)
X_test_count =  count_vect.transform(X_test)

# %% [markdown]
# # Trying four classification models with the TfidfVectorizer
#
# 1. Naive Bayes
# 2. Stochastic Gradient Descent
# 3. Logistic Regression
# 4. Random Forest

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Model 1: Multinomial Naive Bayes Classifier
nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)
y_pred = nb.predict(X_test_tfidf)
print('naive bayes tfidf accuracy %s' % accuracy_score(y_pred, y_test))
# naive bayes tfidf accuracy 0.5289017341040463
# Out:
# naive bayes tfidf accuracy 0.5053720652606446

# %%
from sklearn.linear_model import SGDClassifier

# Model 2: Linear SVM
lsvm = SGDClassifier(alpha=0.001, random_state=5, max_iter=15, tol=None)
lsvm.fit(X_train_tfidf, y_train)
y_pred = lsvm.predict(X_test_tfidf)
print('svm using tfidf accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# svm using tfidf accuracy 0.536808595304417

# %%
from sklearn.linear_model import LogisticRegression

# Model 3: logistic regression
logreg = LogisticRegression(C=1)
logreg.fit(X_train_tfidf, y_train)
y_pred = logreg.predict(X_test_tfidf)
print('log reg tfidf accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# log reg tfidf accuracy 0.52566653402308

# %%
from sklearn.ensemble import RandomForestClassifier

# Model 4: Random Forest Classifier
rf = RandomForestClassifier(n_estimators=500)
rf.fit(X_train_tfidf, y_train)
y_pred = rf.predict(X_test_tfidf)
print('random forest tfidf accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# random forest tfidf accuracy 0.5559092717867091

# %% [markdown]
# # Try the same models but this time with the count vector

# %%
## Building models using count vectors feature
# Model 1: Multinomial Naive Bayes Classifier
nb = MultinomialNB()
nb.fit(X_train_count, y_train)
y_pred = nb.predict(X_test_count)
print('naive bayes count vectors accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# naive bayes count vectors accuracy 0.7934739355352168

# %%
# Model 2: Linear SVM
lsvm = SGDClassifier(alpha=0.001, random_state=5, max_iter=15, tol=None)
lsvm.fit(X_train_count, y_train)
y_pred = lsvm.predict(X_test_count)
print('lsvm using count vectors accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# lsvm using count vectors accuracy 0.7958615200955034

# %%
# Model 3: Logistic Regression
logreg = LogisticRegression(C=1)
logreg.fit(X_train_count, y_train)
y_pred = logreg.predict(X_test_count)
print('log reg count vectors accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# log reg count vectors accuracy 0.7926780740151214

# %%
# Model 4: Random Forest Classifier
rf = RandomForestClassifier(n_estimators=500)
rf.fit(X_train_count, y_train)
y_pred = rf.predict(X_test_count)
print('random forest with count vectors accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# random forest with count vectors accuracy 0.7843215280541186

# %% [markdown]
# It seems like the count vectors are way generally way better - like 20% better.
#
# Now lets try something a little bit more advanced...
#
# # Neural network model

# %%
# Now that the data is cleaned up we need to tokenize it
from tensorflow.keras.preprocessing.sequence import pad_sequences
num_words = 20000
max_length = 100
padding_type = 'post'
trunc_type = 'post'

tokenizer = Tokenizer(num_words=num_words, lower=True)
tokenizer.fit_on_texts(X_train)
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(X_train)
train_padded = pad_sequences(train_sequences, padding = padding_type, maxlen = max_length, truncating = trunc_type)

test_sequences = tokenizer.texts_to_sequences(X_test)
test_padded = pad_sequences(test_sequences, padding = padding_type, maxlen = max_length, truncating = trunc_type)

# %%
training_padded = np.array(train_padded)
training_labels = np.array(y_train)
testing_padded = np.array(test_padded)
testing_labels = np.array(y_test)

training_padded.shape
# Out:
# (5100, 100)

# %%
# The data is tokenized - now lets try putting it in the model
import tensorflow as tf

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
tf.compat.v1.disable_eager_execution()
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

max_words = 100
# Building the CNN Model
model = Sequential()      # initilaizing the Sequential nature for CNN model# Adding the embedding layer which will take in maximum of 450 words as input and provide a 32 dimensional output of those words which belong in the top_words dictionary
model.add(Embedding(20000, 32, input_length=max_words))
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(250, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# create model

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 100, 32)           640000
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 100, 32)           3104
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 250)               400250
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 251
# =================================================================
# Total params: 1,043,605
# Trainable params: 1,043,605
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 20
history = model.fit(training_padded, training_labels,batch_size=128, epochs=num_epochs, 
                    validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Train on 5100 samples, validate on 2513 samples
# Epoch 1/20
# 5100/5100 - 0s - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.8827 - val_accuracy: 0.7776
# Epoch 2/20
# 5100/5100 - 0s - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.8530 - val_accuracy: 0.7696
# Epoch 3/20
# 5100/5100 - 0s - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.8732 - val_accuracy: 0.7736
# Epoch 4/20
# 5100/5100 - 0s - loss: 0.0067 - accuracy: 0.9969 - val_loss: 0.8624 - val_accuracy: 0.7772
# Epoch 5/20
# 5100/5100 - 0s - loss: 0.0059 - accuracy: 0.9967 - val_loss: 0.9273 - val_accuracy: 0.7764
# Epoch 6/20
# 5100/5100 - 0s - loss: 0.0069 - accuracy: 0.9967 - val_loss: 0.8906 - val_accuracy: 0.7756
# Epoch 7/20
# 5100/5100 - 0s - loss: 0.0071 - accuracy: 0.9967 - val_loss: 0.8837 - val_accuracy: 0.7756
# Epoch 8/20
# 5100/5100 - 0s - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.8520 - val_accuracy: 0.7728
# Epoch 9/20
# 5100/5100 - 0s - loss: 0.0058 - accuracy: 0.9965 - val_loss: 0.9566 - val_accuracy: 0.7724
# Epoch 10/20
# 5100/5100 - 0s - loss: 0.0066 - accuracy: 0.9969 - val_loss: 0.8937 - val_accuracy: 0.7764
# Epoch 11/20
# 5100/5100 - 0s - loss: 0.0074 - accuracy: 0.9963 - val_loss: 0.8720 - val_accuracy: 0.7772
# Epoch 12/20
# 5100/5100 - 0s - loss: 0.0069 - accuracy: 0.9967 - val_loss: 0.8340 - val_accuracy: 0.7660
# Epoch 13/20
# 5100/5100 - 0s - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.8874 - val_accuracy: 0.7740
# Epoch 14/20
# 5100/5100 - 0s - loss: 0.0062 - accuracy: 0.9967 - val_loss: 0.8613 - val_accuracy: 0.7764
# Epoch 15/20
# 5100/5100 - 0s - loss: 0.0060 - accuracy: 0.9967 - val_loss: 0.9528 - val_accuracy: 0.7728
# Epoch 16/20
# 5100/5100 - 0s - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.8675 - val_accuracy: 0.7732
# Epoch 17/20
# 5100/5100 - 0s - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.8645 - val_accuracy: 0.7756
# Epoch 18/20
# 5100/5100 - 0s - loss: 0.0062 - accuracy: 0.9961 - val_loss: 0.9396 - val_accuracy: 0.7724
# Epoch 19/20
# 5100/5100 - 0s - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.8530 - val_accuracy: 0.7756
# Epoch 20/20
# 5100/5100 - 0s - loss: 0.0069 - accuracy: 0.9959 - val_loss: 0.8788 - val_accuracy: 0.7740

# %%
# Getting score metrics from our model
scores = model.evaluate(testing_padded, y_test, verbose=0)# Displays the accuracy of correct sentiment prediction over test data
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 77.40%

# %%
# Model 2: Linear SVM
lsvm = SGDClassifier(alpha=0.001, random_state=5, max_iter=15, tol=None)
lsvm.fit(X_train_count, y_train)
y_pred = lsvm.predict(X_test_count)
print('lsvm using count vectors accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# lsvm using count vectors accuracy 0.7958615200955034

# %% [markdown]
# Interesting... it turns out that the lvsm model using count vectors has better accuracy than the convolutional neural network model. Next it could be worth trying one a bidirectional neural network so it is better at seeing the context?
#
# Below are the predictions from the CNN model and then the LVSM models respectively

# %%
X_test_actual = clean_data(validation_data['text'])
actual_test_sequences = tokenizer.texts_to_sequences(X_test_actual)
actual_test_padded = pad_sequences(actual_test_sequences, padding = padding_type, maxlen = max_length, truncating = trunc_type)

predictions = model.predict(actual_test_padded)
predictions
# Out:
# array([[0.02017093],
#        [0.98771703],
#        [0.9981112 ],
#        ...,
#        [0.79837924],
#        [0.98159325],
#        [0.957903  ]], dtype=float32)

# %%
X_test_actual_count_vec =  count_vect.transform(X_test_actual)

predictions = lsvm.predict(X_test_actual_count_vec)
predictions
# Out:
# array([0, 1, 1, ..., 1, 1, 0])
